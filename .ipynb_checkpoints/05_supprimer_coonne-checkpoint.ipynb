# %%
import pandas as pd
df = pd.read_csv("data.csv")

# %%
df
# Out:
#        id first_name   last_name                        email       gender  \
# 0       1    Monique     Caldaro            mcaldaro0@dot.gov       Female
# 1       2      Leigh   Martensen  lmartensen1@accuweather.com         Male
# 2       3   Julianne   Lindstrom         jlindstrom2@yale.edu       Female
# 3       4     Kissee      Levitt      klevitt3@shareasale.com       Female
# 4       5      Nadia    Anthoine           nanthoine4@pbs.org       Female
# ..    ...        ...         ...                          ...          ...
# 995   996      Peggy       Passe           ppassern@about.com       Female
# 996   997     Olivie       Szach         oszachro@answers.com       Female
# 997   998     Glenda  Wellington   gwellingtonrp@amazon.co.jp  Genderqueer
# 998   999    Clemmie       Easum     ceasumrq@dailymail.co.uk         Male
# 999  1000    Corrine    Oxborrow      coxborrowrr@smugmug.com       Female
#
#           ip_address     country  price_paid tax
# ...

# %%
df.drop("ip_address", axis=1,inplace=True)

# %%
df
# Out:
#        id first_name   last_name                        email       gender  \
# 0       1    Monique     Caldaro            mcaldaro0@dot.gov       Female
# 1       2      Leigh   Martensen  lmartensen1@accuweather.com         Male
# 2       3   Julianne   Lindstrom         jlindstrom2@yale.edu       Female
# 3       4     Kissee      Levitt      klevitt3@shareasale.com       Female
# 4       5      Nadia    Anthoine           nanthoine4@pbs.org       Female
# ..    ...        ...         ...                          ...          ...
# 995   996      Peggy       Passe           ppassern@about.com       Female
# 996   997     Olivie       Szach         oszachro@answers.com       Female
# 997   998     Glenda  Wellington   gwellingtonrp@amazon.co.jp  Genderqueer
# 998   999    Clemmie       Easum     ceasumrq@dailymail.co.uk         Male
# 999  1000    Corrine    Oxborrow      coxborrowrr@smugmug.com       Female
#
#         country  price_paid tax
# 0       Ukraine       12.99  US
# ...

# %%
df.set_index("gender", inplace=True)

# %%
df.drop("Female", axis=0, inplace=True)

# %%
df.head()
# Out:
#           id first_name  last_name                        email  \
# gender
# Male       2      Leigh  Martensen  lmartensen1@accuweather.com
# Bigender   6      Flinn     Leward              fleward5@cbc.ca
# Male       7     Pincus    Bottell          pbottell6@umich.edu
# Male       8        Gil   Blissitt    gblissitt7@deviantart.com
# Male       9    Nicolas   Readshaw          nreadshaw8@furl.net
#
#                         country  price_paid tax
# gender
# Male                       Iran        5.49  IT
# Bigender                  China        5.99  DE
# Male      Palestinian Territory       59.99  US
# Male                      China       39.99  IT
# Male                   Cameroon        9.99  US

# %%
df.drop(["first_name","last_name"], axis=1, inplace=True)

# %%
df.head()
# Out:
#           id                        email                country  price_paid  \
# gender
# Male       2  lmartensen1@accuweather.com                   Iran        5.49
# Bigender   6              fleward5@cbc.ca                  China        5.99
# Male       7          pbottell6@umich.edu  Palestinian Territory       59.99
# Male       8    gblissitt7@deviantart.com                  China       39.99
# Male       9          nreadshaw8@furl.net               Cameroon        9.99
#
#          tax
# gender
# Male      IT
# Bigender  DE
# Male      US
# Male      IT
# Male      US

# %%
del df["id"]

# %%
df.head()
# Out:
#                                 email                country  price_paid tax
# gender
# Male      lmartensen1@accuweather.com                   Iran        5.49  IT
# Bigender              fleward5@cbc.ca                  China        5.99  DE
# Male              pbottell6@umich.edu  Palestinian Territory       59.99  US
# Male        gblissitt7@deviantart.com                  China       39.99  IT
# Male              nreadshaw8@furl.net               Cameroon        9.99  US
