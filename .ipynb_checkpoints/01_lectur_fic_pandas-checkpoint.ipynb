# %% [markdown]
# Lecture d'un fichier CSV

# %%
import pandas as pd

# %%
data_frame = pd.read_csv("MOCK_DATA.csv")

# %%
data_frame
# Out:
#        id first_name       last_name                         email  gender  \
# 0       1      Cyndi           Cliss          ccliss0@mapquest.com  Female
# 1       2     Tallou         Ashdown          tashdown1@zimbio.com  Female
# 2       3    Bettina  de Tocqueville    bdetocqueville2@census.gov  Female
# 3       4     Gianna         Evequot             gevequot3@mit.edu  Female
# 4       5      Zared    Jerzykiewicz  zjerzykiewicz4@biglobe.ne.jp    Male
# ..    ...        ...             ...                           ...     ...
# 995   996   Germaine      Kolakowski       gkolakowskirn@nymag.com    Male
# 996   997      Reade          Slisby          rslisbyro@boston.com    Male
# 997   998      Binky          Cranke     bcrankerp@liveinternet.ru    Male
# 998   999       Ewan           Buxcy           ebuxcyrq@seesaa.net    Male
# 999  1000    Brigida         Roberds           broberdsrr@youtu.be  Female
#
#           ip_address
# 0     74.112.105.131
# 1      175.69.25.142
# ...
