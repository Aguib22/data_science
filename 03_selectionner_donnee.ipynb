# %%
import pandas as pd
df = pd.read_csv("MOCK_DATA.csv")

# %%
df.head(10)
# Out:
#    id first_name       last_name                         email  gender  \
# 0   1      Cyndi           Cliss          ccliss0@mapquest.com  Female
# 1   2     Tallou         Ashdown          tashdown1@zimbio.com  Female
# 2   3    Bettina  de Tocqueville    bdetocqueville2@census.gov  Female
# 3   4     Gianna         Evequot             gevequot3@mit.edu  Female
# 4   5      Zared    Jerzykiewicz  zjerzykiewicz4@biglobe.ne.jp    Male
# 5   6   Tallulah        Sudddard  tsudddard5@printfriendly.com  Female
# 6   7  Brittaney         Pischel            bpischel6@time.com  Female
# 7   8  Standford            Ende        sende7@liveinternet.ru    Male
# 8   9     Fabian          Keward       fkeward8@shareasale.com    Male
# 9  10      Jacob        Whitnell            jwhitnell9@loc.gov    Male
#
#         ip_address
# 0   74.112.105.131
# 1    175.69.25.142
# 2   203.100.200.15
# 3  182.111.187.107
# 4      65.249.9.64
# 5     63.119.52.61
# 6    143.231.158.0
# 7   111.246.160.77
# ...

# %%
df["email"].head(5)
# Out:
# 0            ccliss0@mapquest.com
# 1            tashdown1@zimbio.com
# 2      bdetocqueville2@census.gov
# 3               gevequot3@mit.edu
# 4    zjerzykiewicz4@biglobe.ne.jp
# Name: email, dtype: object

# %%
df[10:20]
# Out:
#     id first_name   last_name                       email   gender  \
# 10  11     Graeme     Oxberry         goxberrya@alexa.com     Male
# 11  12     Isidor    Casaccia       icasacciab@senate.gov     Male
# 12  13     Mandel  Dutteridge         mdutteridgec@nhs.uk     Male
# 13  14    Rickert       Kowal        rkowald@omniture.com  Agender
# 14  15      Jabez    Jeschner  jjeschnere@miibeian.gov.cn     Male
# 15  16  Marcellus       Talby          mtalbyf@oracle.com     Male
# 16  17     Shelby   Toffanini  stoffaninig@wikispaces.com   Female
# 17  18      Arlin  Jeandillou         ajeandillouh@un.org     Male
# 18  19     Charis      Murfin     cmurfini@techcrunch.com   Female
# 19  20      Larry       Alpin           lalpinj@prweb.com     Male
#
#          ip_address
# 10    249.61.54.145
# 11    165.253.44.21
# 12   170.232.62.167
# 13    77.44.132.127
# 14   180.209.254.29
# 15  183.122.210.129
# 16   228.239.33.109
# 17    247.28.245.16
# 18   115.240.163.15
# ...

# %%
df_email = df.set_index("email")
df_email.loc["tashdown1@zimbio.com"]
# Out:
# id                        2
# first_name           Tallou
# last_name           Ashdown
# gender               Female
# ip_address    175.69.25.142
# Name: tashdown1@zimbio.com, dtype: object

# %%
type(df_email.loc[["tashdown1@zimbio.com","stoffaninig@wikispaces.com","cmurfini@techcrunch.com"]])
# Out:
# pandas.core.frame.DataFrame
