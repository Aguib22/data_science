# %%
import pandas as pd
df = pd.read_csv("data.csv")

# %%
df["gender"]
# Out:
# 0           Female
# 1             Male
# 2           Female
# 3           Female
# 4           Female
#           ...
# 995         Female
# 996         Female
# 997    Genderqueer
# 998           Male
# 999         Female
# Name: gender, Length: 1000, dtype: object

# %%
df[df["gender"] == "Male"]
# Out:
#       id first_name  last_name                        email gender  \
# 1      2      Leigh  Martensen  lmartensen1@accuweather.com   Male
# 6      7     Pincus    Bottell          pbottell6@umich.edu   Male
# 7      8        Gil   Blissitt    gblissitt7@deviantart.com   Male
# 8      9    Nicolas   Readshaw          nreadshaw8@furl.net   Male
# 11    12     Samson    Cockill          scockillb@topsy.com   Male
# ..   ...        ...        ...                          ...    ...
# 980  981      Romeo     Masser         rmasserr8@hao123.com   Male
# 987  988       Nero     Smeeth           nsmeethrf@phoca.cz   Male
# 992  993     Timmie   Pickover     tpickoverrk@google.co.uk   Male
# 994  995        Van      Banke             vbankerm@epa.gov   Male
# 998  999    Clemmie      Easum     ceasumrq@dailymail.co.uk   Male
#
#          ip_address                country  price_paid tax
# 1     66.128.123.92                   Iran        5.49  IT
# ...

# %%
country_filter = df.country.isin(["France","Canada"])

# %%
df[country_filter]
# Out:
#       id  first_name       last_name                          email  \
# 44    45        Flem         Hulburd        fhulburd18@slashdot.org
# 62    63        Wynn  Van der Brugge        wvanderbrugge1q@com.com
# 63    64       Eldon            Haws              ehaws1r@google.ru
# 64    65     Abrahan         Bierman     abierman1s@hugedomains.com
# 130  131      Pieter      Hardcastle  phardcastle3m@bizjournals.com
# 142  143        Zola           Flinn             zflinn3y@fotki.com
# 183  184    Kingsley           Trime              ktrime53@tamu.edu
# 199  200        Lida           Latch         llatch5j@artisteer.com
# 262  263     Pacorro         Dollard        pdollard7a@netvibes.com
# 272  273      Hollis        Posnette           hposnette7k@cnet.com
# 277  278      Reggis          Mulbry         rmulbry7p@mapquest.com
# 327  328       Aline          Daspar              adaspar93@mapy.cz
# 338  339       Fabio          Rathke            frathke9e@umich.edu
# ...

# %%
df[df["price_paid"] > 5.0]
# Out:
#        id first_name  last_name                        email       gender  \
# 0       1    Monique    Caldaro            mcaldaro0@dot.gov       Female
# 1       2      Leigh  Martensen  lmartensen1@accuweather.com         Male
# 2       3   Julianne  Lindstrom         jlindstrom2@yale.edu       Female
# 4       5      Nadia   Anthoine           nanthoine4@pbs.org       Female
# 5       6      Flinn     Leward              fleward5@cbc.ca     Bigender
# ..    ...        ...        ...                          ...          ...
# 986   987    Suellen   Vannucci         svannuccire@lulu.com       Female
# 989   990    Virgina       Turk          vturkrh@harvard.edu  Genderqueer
# 994   995        Van      Banke             vbankerm@epa.gov         Male
# 998   999    Clemmie      Easum     ceasumrq@dailymail.co.uk         Male
# 999  1000    Corrine   Oxborrow      coxborrowrr@smugmug.com       Female
#
#           ip_address    country  price_paid tax
# ...
