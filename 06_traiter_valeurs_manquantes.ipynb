# %%
import pandas as pd
df = pd.read_csv("data.csv")

# %%
df.isnull()
# Out:
#         id  first_name  last_name  email  gender  ip_address  country  \
# 0    False       False      False  False   False       False    False
# 1    False       False      False  False   False       False    False
# 2    False       False      False  False   False       False    False
# 3    False       False      False  False   False       False    False
# 4    False       False      False  False   False       False    False
# ..     ...         ...        ...    ...     ...         ...      ...
# 995  False       False      False  False   False       False    False
# 996  False       False      False  False   False       False    False
# 997  False       False      False  False   False       False    False
# 998  False       False      False  False   False       False    False
# 999  False       False      False  False   False       False    False
#
#      price_paid    tax
# 0         False  False
# 1         False  False
# 2         False  False
# 3         False  False
# 4         False  False
# ..          ...    ...
# 995       False  False
# 996       False  False
# 997       False  False
# 998       False  False
# 999       False  False
#
# [1000 rows x 9 columns]

# %%
df.notnull()
# Out:
#        id  first_name  last_name  email  gender  ip_address  country  \
# 0    True        True       True   True    True        True     True
# 1    True        True       True   True    True        True     True
# 2    True        True       True   True    True        True     True
# 3    True        True       True   True    True        True     True
# 4    True        True       True   True    True        True     True
# ..    ...         ...        ...    ...     ...         ...      ...
# 995  True        True       True   True    True        True     True
# 996  True        True       True   True    True        True     True
# 997  True        True       True   True    True        True     True
# 998  True        True       True   True    True        True     True
# 999  True        True       True   True    True        True     True
#
#      price_paid   tax
# 0          True  True
# 1          True  True
# 2          True  True
# 3          True  True
# 4          True  True
# ..          ...   ...
# 995        True  True
# 996        True  True
# 997        True  True
# 998        True  True
# 999        True  True
#
# [1000 rows x 9 columns]

# %%
df.tax.fillna(0)
# Out:
# 0      US
# 1      IT
# 2      DE
# 3      IT
# 4      DE
#        ..
# 995    DE
# 996    IT
# 997    AT
# 998    DE
# 999    AT
# Name: tax, Length: 1000, dtype: object

# %%
df[~df["gender"].isin(["Male","Female"])]
# Out:
#       id   first_name   last_name                             email  \
# 5      6        Flinn      Leward                   fleward5@cbc.ca
# 10    11         Yvon       Nucci                ynuccia@flavors.me
# 13    14        Gerik      Fowden             gfowdend@edublogs.org
# 40    41  Barbaraanne       Likly              blikly14@dedecms.com
# 43    44        Ailee  Mazonowicz             amazonowicz17@loc.gov
# ..   ...          ...         ...                               ...
# 954  955      Daphene   Greetland  dgreetlandqi@creativecommons.org
# 972  973       Kathie     Lartice       klarticer0@domainmarket.com
# 989  990      Virgina        Turk               vturkrh@harvard.edu
# 993  994       Karlie      Clancy               kclancyrl@nifty.com
# 997  998       Glenda  Wellington        gwellingtonrp@amazon.co.jp
#
#           gender       ip_address    country  price_paid tax
# 5       Bigender    201.6.219.199      China        5.99  DE
# 10   Genderfluid    120.56.150.26    Armenia       49.99  US
# 13   Genderfluid  136.249.196.166       Peru       18.99  US
# 40      Bigender    2.149.204.254  Indonesia        4.99  US
# 43    Polygender    150.169.214.6      Japan       12.99  US
# ..           ...              ...        ...         ...  ..
# 954  Genderqueer   160.197.139.52  Indonesia       29.99  US
# 972  Genderqueer  142.159.114.187     Greece       29.99  US
# 989  Genderqueer    223.16.242.83     Angola       19.99  US
# 993     Bigender     187.41.97.27  Venezuela        1.99  DE
# 997  Genderqueer   166.157.66.209      China        3.99  AT
#
# [99 rows x 9 columns]

# %%
df.loc[~df["gender"].isin(["Male", "Female"]), "gender"] = pd.NA

# %%
df.isnull()
# Out:
#         id  first_name  last_name  email  gender  ip_address  country  \
# 0    False       False      False  False   False       False    False
# 1    False       False      False  False   False       False    False
# 2    False       False      False  False   False       False    False
# 3    False       False      False  False   False       False    False
# 4    False       False      False  False   False       False    False
# ..     ...         ...        ...    ...     ...         ...      ...
# 995  False       False      False  False   False       False    False
# 996  False       False      False  False   False       False    False
# 997  False       False      False  False    True       False    False
# 998  False       False      False  False   False       False    False
# 999  False       False      False  False   False       False    False
#
#      price_paid    tax
# 0         False  False
# 1         False  False
# 2         False  False
# 3         False  False
# 4         False  False
# ..          ...    ...
# 995       False  False
# 996       False  False
# 997       False  False
# 998       False  False
# 999       False  False
#
# [1000 rows x 9 columns]

# %%
df.notnull()
# Out:
#        id  first_name  last_name  email  gender  ip_address  country  \
# 0    True        True       True   True    True        True     True
# 1    True        True       True   True    True        True     True
# 2    True        True       True   True    True        True     True
# 3    True        True       True   True    True        True     True
# 4    True        True       True   True    True        True     True
# ..    ...         ...        ...    ...     ...         ...      ...
# 995  True        True       True   True    True        True     True
# 996  True        True       True   True    True        True     True
# 997  True        True       True   True   False        True     True
# 998  True        True       True   True    True        True     True
# 999  True        True       True   True    True        True     True
#
#      price_paid   tax
# 0          True  True
# 1          True  True
# 2          True  True
# 3          True  True
# 4          True  True
# ..          ...   ...
# 995        True  True
# 996        True  True
# 997        True  True
# 998        True  True
# 999        True  True
#
# [1000 rows x 9 columns]

# %%
df[~df["gender"].isin(["Male","Female"])]
# Out:
#       id   first_name   last_name                             email gender  \
# 5      6        Flinn      Leward                   fleward5@cbc.ca   <NA>
# 10    11         Yvon       Nucci                ynuccia@flavors.me   <NA>
# 13    14        Gerik      Fowden             gfowdend@edublogs.org   <NA>
# 40    41  Barbaraanne       Likly              blikly14@dedecms.com   <NA>
# 43    44        Ailee  Mazonowicz             amazonowicz17@loc.gov   <NA>
# ..   ...          ...         ...                               ...    ...
# 954  955      Daphene   Greetland  dgreetlandqi@creativecommons.org   <NA>
# 972  973       Kathie     Lartice       klarticer0@domainmarket.com   <NA>
# 989  990      Virgina        Turk               vturkrh@harvard.edu   <NA>
# 993  994       Karlie      Clancy               kclancyrl@nifty.com   <NA>
# 997  998       Glenda  Wellington        gwellingtonrp@amazon.co.jp   <NA>
#
#           ip_address    country  price_paid tax
# 5      201.6.219.199      China        5.99  DE
# 10     120.56.150.26    Armenia       49.99  US
# 13   136.249.196.166       Peru       18.99  US
# 40     2.149.204.254  Indonesia        4.99  US
# 43     150.169.214.6      Japan       12.99  US
# ..               ...        ...         ...  ..
# 954   160.197.139.52  Indonesia       29.99  US
# 972  142.159.114.187     Greece       29.99  US
# 989    223.16.242.83     Angola       19.99  US
# 993     187.41.97.27  Venezuela        1.99  DE
# 997   166.157.66.209      China        3.99  AT
#
# [99 rows x 9 columns]

# %%
df.dropna(subset=["gender"])
# Out:
#        id first_name  last_name                        email  gender  \
# 0       1    Monique    Caldaro            mcaldaro0@dot.gov  Female
# 1       2      Leigh  Martensen  lmartensen1@accuweather.com    Male
# 2       3   Julianne  Lindstrom         jlindstrom2@yale.edu  Female
# 3       4     Kissee     Levitt      klevitt3@shareasale.com  Female
# 4       5      Nadia   Anthoine           nanthoine4@pbs.org  Female
# ..    ...        ...        ...                          ...     ...
# 994   995        Van      Banke             vbankerm@epa.gov    Male
# 995   996      Peggy      Passe           ppassern@about.com  Female
# 996   997     Olivie      Szach         oszachro@answers.com  Female
# 998   999    Clemmie      Easum     ceasumrq@dailymail.co.uk    Male
# 999  1000    Corrine   Oxborrow      coxborrowrr@smugmug.com  Female
#
#           ip_address     country  price_paid tax
# 0    162.151.214.246     Ukraine       12.99  US
# 1      66.128.123.92        Iran        5.49  IT
# 2      214.195.22.61   Argentina       24.99  DE
# 3       67.49.26.158      Mexico        3.79  IT
# 4      67.102.139.96       Chile       49.99  DE
# ..               ...         ...         ...  ..
# 994   143.162.26.237    Thailand       45.00  NL
# 995    84.29.107.251      Russia        4.29  DE
# 996    136.14.73.176  Bangladesh        2.99  IT
# 998   34.100.141.181      Israel       29.99  DE
# 999    47.201.95.226    Pakistan       24.99  AT
#
# [901 rows x 9 columns]
